# %%
# Run below cell and generate your dynamic course plan
# Novigate to Modules folder for the Course and quizzes generated
import warnings
warnings.filterwarnings('ignore')

# %run pyfiles/course_selector_ui
# Out:
# Loaded 26 unique concepts and 32 LOs.
# VBox(children=(HTML(value='<h2>Quantum Course Builder</h2>'), Button(button_style='info', description='Resume …
