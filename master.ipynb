# %% [markdown]
# # Course Index: Foundations of Quantum Communication & Cryptography
#
# Welcome to the course! This notebook serves as the main index for all learning modules. Use the links in the table below to navigate to each topic.

# %% [markdown]
# | Unit                                        | Topic                                | Description & Learning Objectives                                                                                                                                                              | Notebook Link  |
# |---------------------------------------------|--------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|----------------|
# | Unit 1: Quantum Foundations                 | 1.1: The Qubit                       | Defines classical bits and qubits                                                                                                                                                           | [Go to Notebook](content/unit01_quantum_foundations/01_the_qbit/01_the_qbit.ipynb)      |
# |                                             | 1.2: Quantum Phenomena               | Introduces different measurement bases, Entanglement, and Decoherence. Includes interactive games to model these phenomena.                                                                    |  [Go to Notebook](content/unit01_quantum_foundations/02_quantum_phenomena/02_quantum_phenomena.ipynb)                |
# | Unit 2: Principles of Quantum Communication | 2.1: Fundamental Rules               | Explains the No-Cloning Theorem and its critical implications for quantum security. Includes a conceptual quiz.                                                                                |  [Go to Notebook](content/unit02_principles_of_quantum_communication/03_fundamental_rules/03_fundamental_rules.ipynb) |
# |                                             | 2.2: Core Protocols                  | Describes the components of a quantum network and outlines the steps for Quantum Teleportation. Includes simulation activities.                                                                |    [Go to Notebook](content/unit02_principles_of_quantum_communication/04_core_protocols/04_core_protocols.ipynb)             |
# | Unit 3: Quantum & Post-Quantum Cryptography | 3.1: Quantum Key Distribution (QKD)  | Details the principles of secure key exchange using the BB84 protocol and demonstrates how to detect an eavesdropper.                                                                          |  [Go to Notebook](content/unit03_quantum_and_post_quantum_cryptography/05_quantum_key_distribution/05_quantum_key_distribution.ipynb) |
# |                                             | 3.2: Post-Quantum Cryptography (PQC) | Defines the threat quantum computers pose to classical cryptography, differentiates QKD from PQC, and provides a hands-on lab to encrypt/decrypt a message using the ML-KEM (Kyber) algorithm. |    [Go to Notebook](content/unit03_quantum_and_post_quantum_cryptography/06_post_quantum_cryptography/06_post_quantum_cryptography.ipynb)             |
