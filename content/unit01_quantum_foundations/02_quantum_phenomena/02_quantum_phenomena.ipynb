# %% [markdown]
# # 2. Quantum Phenomena
#
# **Learning Outcomes:**
#
# Upon completion of this lesson:
#
# 2.1 Students will understand the basics of measuring a qubit.
#
# 2.2 Reinforce basis selection using the Quantum Space Explorer Game
#
# 2.3 Students will understand the notion of entangled quantum systems.
#
# 2.4 Students will understand the notion of entangled decoherence systems.
#
# 2.5 Model Entanglement and Decoherence using the Quantum Snakes and Ladders Game.

# %% [markdown]
# ## 2.1 Measuring a Qubit
#
# Let's discuss single-qubit measurements. So far we've said that a qubit $\rvert\psi\rangle=\alpha\rvert0\rangle+\beta\rvert1\rangle$ collapses to $\rvert0\rangle$ with probability $\rvert\alpha\rvert^2$ and to $\left|1\right>$ with probability $\rvert\beta\rvert^2$.
#
# Quantum mechanics says that any device used to measure a two-state quantum system must have two states that are its preferred states that form an orthonormal basis for the corresponding two-dimensional vector space. We denote these by $\{\rvert v\rangle, \rvert v^\perp\rangle\}$. Measurement then transforms the quantum state being measured into one of these two preferred states. And the probabilities for these transformations are given by the modulus squared of the corresponding amplitudes. Further, this property of quantum systems is based on empirical observations and not derived from any other physical laws.
#
# Therefore, we must specify the basis being used for measurement when we say "measure a qubit". If no basis is specified then a standard basis is assumed.
#
# Also, this implies that measurement changes the state of a quantum system. Consequently, if a qubit $\rvert\psi\rangle=\alpha\rvert v\rangle+\beta\rvert v^\perp\rangle$ is measured and it collapses to $\rvert v^\perp\rangle$ then a second measurement in the same basis will always result in state $\rvert v^\perp\rangle$ with probability 1 because now the amplitude of $\rvert v\rangle$ is zero.
#
# ### Loss of information
#
# From the above discussion it is clear that unless the qubit is already in one of the basis states, a measurement will change the state of the qubit and the original state of the qubit will be lost forever.
#
# Further, this postulate of quantum mechanics says that although a qubit has infinite possible states, we can only extract one bit of information out of it because the qubit has to collapse to one of the two possible basis states (representing one bit of information).
#
# Also, distinct quantum states may have same probabilities of collapse. For example, $\frac{1}{\sqrt{2}}(\rvert0\rangle+\rvert1\rangle)$, $\frac{1}{\sqrt{2}}(\rvert0\rangle-\rvert1\rangle)$ and $\frac{1}{\sqrt{2}}(i\rvert0\rangle-\rvert1\rangle)$ all have exactly the same probabilities of collapse in the standard basis but are completely distinct quantum states that behave differently in other circumstances.

# %% [markdown]
# ## 2.2 Quantum Space Explorer Game

# %%
from IPython.display import IFrame

IFrame(src='../../../games/ozma/dist/index.html', width='100%', height=1000)
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="../../../games/ozma/dist/index.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 2.3 Understanding Quantum Entanglement
#
# Quantum entanglement is one of the most fascinating and non-intuitive ideas in quantum mechanics. At its core, entanglement is a special connection between two or more quantum particles, linking them in a way that their fates are intertwined, no matter how far apart they are.
#
# Think of it like having a pair of "magic coins." 🪙—🪙 You and a friend each take one coin, and you travel to opposite sides of the world. Before you look, you know that if your coin lands on heads, your friend's coin will instantly land on tails, and vice-versa. There's a perfect correlation between them. Entangled particles behave similarly. If you measure a property of one particle (like its spin), you instantly know the corresponding property of its entangled partner.
#
# This "spooky action at a distance," as Einstein famously called it, doesn't allow for faster-than-light communication, but it is a fundamental resource in quantum computing and networking.

# %% [markdown]
# ## 2.4 Understanding Decoherence in Entangled Systems
#
# If entanglement is the special, quiet connection between particles, decoherence is the process that breaks that connection due to interference from the outside world.
#
# Imagine you and your friend with the magic coins are trying to communicate in a perfectly quiet library—that's entanglement. Now, imagine someone opens the doors and a loud, chaotic crowd rushes in. The noise makes it impossible to maintain your quiet connection. Decoherence is like that environmental "noise" for a quantum system.
#
# Any interaction with the outside environment—a stray magnetic field, a change in temperature, or even a single photon bumping into one of the particles—can disrupt the delicate entangled state. This causes the particles to "decohere," meaning they lose their quantum properties and their special connection, and begin to behave like normal, independent classical objects. Protecting quantum systems from decoherence is one of the biggest challenges in building a functional quantum computer.

# %% [markdown]
# ## 2.5 Model Entanglement and Decoherence using the Quantum Snakes and Ladders Game.

# %%
from IPython.display import IFrame

IFrame(src='../../../games/snake_n_ladders/dist/index.html', width='100%', height=1000)
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="../../../games/snake_n_ladders/dist/index.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
